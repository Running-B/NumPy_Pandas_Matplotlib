# %% [markdown]
# 在数据可视化的结果中用图形将误差有效地显示出来，就可以提供更充分的信息。

# %% [markdown]
# # 1-基本误差线 errorbar
#     通过一个 Matplotlib 函数来创建

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

# yerr 垂直方向误差线，xerr 水平方向误差线
plt.errorbar(x,y,yerr=dy,fmt='.k');

# %% [markdown]
# 其中，fmt 是一种控制线条和点的外观的代码格式，语法与 plt.plot 的缩写代码相同。

# %% [markdown]
# errorbar 还有许多改善结果的选项。通过这些额外的选项，可以轻松自定义误差线图形的绘画风格。一般，让误差线的颜色比数据点的颜色浅一点效果会非常好，尤其是在那些比较密集的图形中。

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0);

# %% [markdown]
# 还可以设置水平方向的误差线（xerr）、单侧误差线（one-sided errorbar），以及其他形式的误差线。
